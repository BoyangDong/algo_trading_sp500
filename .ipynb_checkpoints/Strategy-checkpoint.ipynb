# %%
from pandas_datareader import data as pdr

# %%
tickers = ['spy', 'AAPL'] 
df = pdr.DataReader(tickers, data_source='yahoo', start='2015-05-01', end='2021-05-01')
df.tail(5)
# Out:
# Attributes   Adj Close                   Close                    High  \
# Symbols            spy        AAPL         spy        AAPL         spy
# Date
# 2021-04-26  414.918945  134.094650  417.609985  134.720001  418.220001
# 2021-04-27  414.829529  133.766174  417.519989  134.389999  418.140015
# 2021-04-28  414.710297  132.959930  417.399994  133.580002  419.010010
# 2021-04-29  417.353149  132.860397  420.059998  133.479996  420.720001
# 2021-04-30  414.610931  130.849777  417.299988  131.460007  418.540009
#
# Attributes                     Low                    Open              \
# Symbols           AAPL         spy        AAPL         spy        AAPL
# Date
# 2021-04-26  135.059998  416.809998  133.559998  417.440002  134.830002
# 2021-04-27  135.410004  416.299988  134.110001  417.929993  135.009995
# 2021-04-28  135.020004  416.899994  133.080002  417.809998  134.309998
# 2021-04-29  137.070007  416.440002  132.449997  420.320007  136.470001
# ...

# %%
close = df['Close']

# %%
all_weekdays = pd.date_range(start=start_date, end=end_date, freq='B')
close = close.reindex(all_weekdays)

# %%
close.describe()
# Out:
# Symbols         spy        AAPL
# count    422.000000  422.000000
# mean     207.948199   27.588726
# std        8.952338    2.581096
# min      182.860001   22.584999
# 25%      203.592499   25.398125
# 50%      208.959999   27.626249
# 75%      213.417500   29.145000
# max      227.759995   33.134998

# %%
# Relative returns
returns = df['Close'].pct_change(1)
returns.head()
# Out:
# Symbols          spy      AAPL
# Date
# 2015-05-01       NaN       NaN
# 2015-05-04  0.002847 -0.001939
# 2015-05-05 -0.011452 -0.022533
# 2015-05-06 -0.004117 -0.006280
# 2015-05-07  0.003990  0.002000

# %%
log_returns = np.log(df['Close']).diff()
log_returns.head()
# Out:
# Symbols          spy      AAPL
# Date
# 2015-05-01       NaN       NaN
# 2015-05-04  0.002843 -0.001941
# 2015-05-05 -0.011518 -0.022791
# 2015-05-06 -0.004125 -0.006300
# 2015-05-07  0.003982  0.001998

# %%
r_t = log_returns.tail(1).transpose()
r_t
# Out:
# Date     2021-04-30
# Symbols
# spy       -0.006592
# AAPL      -0.015249

# %%
# Weights as defined above
weights_vector = pd.DataFrame(1/len(tickers), index=r_t.index, columns=r_t.columns)
#weights_vector

# %%
# Total log_return for the portfolio is:
portfolio_log_return = weights_vector.transpose().dot(r_t)
#portfolio_log_return

# %%
weights_matrix = pd.DataFrame(1/len(tickers), index=r_t.index, columns=r_t.columns)
#weights_matrix.tail()

# %%
data = close
data = data.dropna()
data
# Out:
# Symbols            spy       AAPL
# 2015-05-01  210.720001  32.237499
# 2015-05-04  211.320007  32.174999
# 2015-05-05  208.899994  31.450001
# 2015-05-06  208.039993  31.252501
# 2015-05-07  208.869995  31.315001
# ...                ...        ...
# 2016-12-23  225.710007  29.129999
# 2016-12-27  226.270004  29.315001
# 2016-12-28  224.399994  29.190001
# 2016-12-29  224.350006  29.182501
# 2016-12-30  223.529999  28.955000
#
# [422 rows x 2 columns]

# %%
short_rolling = data.rolling(window=20).mean()
long_rolling = data.rolling(window=100).mean()

# %%
start_date = '2015-01-01'
end_date = '2016-12-31'
fig, ax = plt.subplots(figsize=(16,9))

ax.plot(data.loc[start_date:end_date, :].index, data.loc[start_date:end_date, 'spy'], label='Price')
ax.plot(long_rolling.loc[start_date:end_date, :].index, long_rolling.loc[start_date:end_date, 'spy'], label = '100-days SMA')
ax.plot(short_rolling.loc[start_date:end_date, :].index, short_rolling.loc[start_date:end_date, 'spy'], label = '20-days SMA')

ax.legend(loc='best')
ax.set_ylabel('Price in $')
ax.xaxis.set_major_formatter(my_year_month_fmt)

# %%
# Using Pandas to calculate a 20-days span EMA. adjust=False specifies only the recursive calculation mode is interested.
ema_short = data.ewm(span=20, adjust=False).mean()

fig, ax = plt.subplots(figsize=(15,9))

ax.plot(data.loc[start_date:end_date, :].index, data.loc[start_date:end_date, 'spy'], label='Price')
ax.plot(ema_short.loc[start_date:end_date, :].index, ema_short.loc[start_date:end_date, 'spy'], label = 'Span 20-days EMA')
ax.plot(short_rolling.loc[start_date:end_date, :].index, short_rolling.loc[start_date:end_date, 'spy'], label = '20-days SMA')

ax.legend(loc='best')
ax.set_ylabel('Price in $')
ax.xaxis.set_major_formatter(my_year_month_fmt)

# %%
# check the price timeseries crosses the EMA timeseries
# then apply weights to each equity, initial fund are split cross all 3 assets 
trading_positions_raw = data - ema_short
trading_positions_raw.tail()
# Out:
# Symbols          spy      AAPL
# 2016-12-23  1.725083  0.563149
# 2016-12-27  2.067454  0.676898
# 2016-12-28  0.178639  0.499336
# 2016-12-29  0.116399  0.444995
# 2016-12-30 -0.636598  0.196780

# %%
trading_positions = trading_positions_raw.apply(np.sign) * 1/len(tickers)
trading_positions.tail()
# Out:
# Symbols     spy  AAPL
# 2016-12-23  0.5   0.5
# 2016-12-27  0.5   0.5
# 2016-12-28  0.5   0.5
# 2016-12-29  0.5   0.5
# 2016-12-30 -0.5   0.5

# %%
trading_positions_final = trading_positions.shift(1)

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(16,9))

ax1.plot(data.loc[start_date:end_date, :].index, data.loc[start_date:end_date, 'spy'], label='Price')
ax1.plot(ema_short.loc[start_date:end_date, :].index, ema_short.loc[start_date:end_date, 'spy'], label = 'Span 20-days EMA')

ax1.set_ylabel('$')
ax1.legend(loc='best')
ax1.xaxis.set_major_formatter(my_year_month_fmt)

ax2.plot(trading_positions_final.loc[start_date:end_date, :].index, trading_positions_final.loc[start_date:end_date, 'spy'], 
        label='Trading position')

ax2.set_ylabel('Trading position')
ax2.xaxis.set_major_formatter(my_year_month_fmt)

# %%
asset_log_returns = np.log(data).diff()
asset_log_returns.head()
# Out:
# Symbols          spy      AAPL
# 2015-05-01       NaN       NaN
# 2015-05-04  0.002843 -0.001941
# 2015-05-05 -0.011518 -0.022791
# 2015-05-06 -0.004125 -0.006300
# 2015-05-07  0.003982  0.001998

# %%
strategy_asset_log_returns = trading_positions_final * asset_log_returns
strategy_asset_log_returns.tail()
# Out:
# Symbols          spy      AAPL
# 2016-12-23  0.000732  0.000988
# 2016-12-27  0.001239  0.003165
# 2016-12-28 -0.004149 -0.002137
# 2016-12-29 -0.000111 -0.000128
# 2016-12-30 -0.001831 -0.003913

# %%
# Get the cumulative log-returns per asset
cum_strategy_asset_log_returns = strategy_asset_log_returns.cumsum()

# Transform the cumulative log returns to relative returns
cum_strategy_asset_relative_returns = np.exp(cum_strategy_asset_log_returns) - 1

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(16,9))

for c in asset_log_returns:
    ax1.plot(cum_strategy_asset_log_returns.index, cum_strategy_asset_log_returns[c], label=str(c))

ax1.set_ylabel('Cumulative log-returns')
ax1.legend(loc='best')
ax1.xaxis.set_major_formatter(my_year_month_fmt)

for c in asset_log_returns:
    ax2.plot(cum_strategy_asset_relative_returns.index, 100*cum_strategy_asset_relative_returns[c], label=str(c))

ax2.set_ylabel('Total relative returns (%)')
ax2.legend(loc='best')
ax2.xaxis.set_major_formatter(my_year_month_fmt)

# %%
# Total strategy relative returns. This is the exact calculation.
cum_relative_return_exact = cum_strategy_asset_relative_returns.sum(axis=1)

# Get the cumulative log-returns per asset
cum_strategy_log_return = cum_strategy_asset_log_returns.sum(axis=1)

# Transform the cumulative log returns to relative returns. This is the approximation
cum_relative_return_approx = np.exp(cum_strategy_log_return) - 1

fig, ax = plt.subplots(figsize=(16,9))

ax.plot(cum_relative_return_exact.index, 100*cum_relative_return_exact, label='Exact')
ax.plot(cum_relative_return_approx.index, 100*cum_relative_return_approx, label='Estimated')

ax.set_ylabel('Cumulative relative returns')
ax.legend(loc='best')
ax.xaxis.set_major_formatter(my_year_month_fmt)

# %%
def print_portfolio_yearly_statistics(portfolio_cumulative_relative_returns, days_per_year = 52 * 5):

    total_days_in_simulation = portfolio_cumulative_relative_returns.shape[0]
    number_of_years = total_days_in_simulation / days_per_year

    # The last data point will give us the total portfolio return
    total_portfolio_return = portfolio_cumulative_relative_returns[-1]
    # Average portfolio return assuming compunding of returns
    average_yearly_return = (1 + total_portfolio_return)**(1/number_of_years) - 1

    print('Total portfolio return is: ' + '{:5.2f}'.format(100*total_portfolio_return) + '%')
    print('Average yearly return is: ' + '{:5.2f}'.format(100*average_yearly_return) + '%')

print_portfolio_yearly_statistics(cum_relative_return_exact)
# Out:
# Total portfolio return is: 14.94%
# Average yearly return is:  8.96%
